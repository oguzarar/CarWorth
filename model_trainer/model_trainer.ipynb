# %%
import pandas as pd
from catboost import CatBoostRegressor

# %%
cd=pd.read_csv("cars.csv")

# %%
cd.to_csv("cars.csv")

# %%
cd.head(15)
# Out:
#     Unnamed: 0                                             baslik  konum  \
# 0            0  2022 MEGANE 1.3 TCE 140 HP JOY COMFORT EDC SER...  Adana
# 1            1  2022 SKODA OCTAVİA 1.0 E-TEC ELİTE DSG SERVİS ...  Adana
# 2            2             Sahibinden HATASIZ BOYASIZ Peugeot 207  Adana
# 3            3  BEY CLASS'TAN AUDİ A4 QUATRO S-TRONİC 177 HP D...  Adana
# 4            4  2021 TOYOTA COROLLA 1.5 DREAM HATASIZ BOYASIZ ...  Adana
# 5            5      Galeriden Peugeot 206 1.6 CC 2003 Model Adana  Adana
# 6            6  Galeriden Peugeot 207 1.4 HDi Trendy 2007 Mode...  Adana
# 7            7  2021 COROLLA 1.5DREAM HATASIZBOYASIZ 18 BİNKM ...  Adana
# 8            8  Galeriden Volkswagen Golf 1.4 TSi Highline 201...  Adana
# 9            9  SGZ MOTORS 2020 EGEA URBAN PLUS HATASIZ BOYASI...  Adana
# 10          10  BOYASIZ - DEĞİŞENSİZ - HATASIZ  Volkswagen Gol...  Adana
# 11          11  ESG Motors | 99 Honda Civic İes Lacivert Trame...  Adana
# 12          12    ÖZTÜRK AUTO’DAN EMSALSİZ TEMİZLİKTE BMW 320 İED  Adana
# 13          13  2025 ÇIKŞLI YENİ KASA RENAULT CLİO 1.0TCE ALPİ...  Adana
# 14          14                                Orijinal Temiz araç  Adana
#
#         fiyat      ilan_tarihi       marka      seri  \
# 0   1169000.0  21 Ağustos 2025     Renault    Megane
# 1   1520000.0  21 Ağustos 2025       Skoda   Octavia
# 2    469999.0  19 Ağustos 2025     Peugeot       207
# 3   1150000.0  19 Ağustos 2025        Audi        A4
# 4   1430000.0  19 Ağustos 2025      Toyota   Corolla
# 5    375000.0  19 Ağustos 2025     Peugeot       206
# 6    456000.0  16 Ağustos 2025     Peugeot       207
# 7   1465000.0  16 Ağustos 2025      Toyota   Corolla
# 8    975000.0  16 Ağustos 2025  Volkswagen      Golf
# 9    814900.0  15 Ağustos 2025        Fiat      Egea
# 10   785000.0  15 Ağustos 2025  Volkswagen      Golf
# 11   352500.0  15 Ağustos 2025       Honda     Civic
# 12  1115000.0  14 Ağustos 2025         BMW  3 Serisi
# 13  1385000.0  14 Ağustos 2025     Renault      Clio
# 14  1580000.0  14 Ağustos 2025  Volkswagen      Golf
#
#                              model   yil  kilometre  ... motor_gucu  \
# 0              1.3 TCe Joy Comfort  2022   124000.0  ...      138.0
# 1                  1.0 e-Tec Elite  2022    99000.0  ...      113.0
# 2                       1.4 Trendy  2009   207500.0  ...       91.0
# 3         A4 Sedan 2.0 TDI Quattro  2013   219000.0  ...      188.0
# 4                        1.5 Dream  2021    63000.0  ...      125.0
# 5                           1.6 CC  2003   249000.0  ...      110.0
# 6                   1.4 HDi Trendy  2007   226000.0  ...       69.0
# 7                        1.5 Dream  2021    18000.0  ...      113.0
# 8                 1.4 TSi Highline  2013   228000.0  ...      122.0
# 9              1.4 Fire Urban Plus  2020    39000.0  ...       95.0
# 10               1.4 TSi Trendline  2011   245000.0  ...      122.0
# 11                         1.4 i S  1999   325000.0  ...       90.0
# 12                  320i ED M Plus  2014   238000.0  ...      170.0
# 13    1.0 TCe Techno Esprit Alpine  2024     9200.0  ...       88.0
# 14  1.6 TDi BlueMotion Comfortline  2019    83000.0  ...      113.0
#
#             cekis arac_durumu ortalama_yakit_tuketimi  yakit_deposu  \
# 0     Önden Çekiş   İkinci El                     5.3          50.0
# 1     Önden Çekiş   İkinci El                     4.3          48.0
# 2     Önden Çekiş   İkinci El                     6.3          50.0
# 3   4WD (Sürekli)   İkinci El                     5.1          63.0
# 4     Önden Çekiş   İkinci El                     5.8          50.0
# 5     Önden Çekiş   İkinci El                     6.9          47.0
# 6     Önden Çekiş   İkinci El                     4.5          50.0
# 7     Önden Çekiş   İkinci El                     5.8          50.0
# 8     Önden Çekiş   İkinci El                     5.0          50.0
# 9     Önden Çekiş   İkinci El                     5.7          45.0
# 10    Önden Çekiş   İkinci El                     6.2          55.0
# 11    Önden Çekiş   İkinci El                     6.8          45.0
# 12   Arkadan İtiş   İkinci El                     5.3          60.0
# 13    Önden Çekiş   İkinci El                     6.0          42.0
# 14    Önden Çekiş   İkinci El                     3.9          50.0
#
#            boya_degisen      kimden   tramer  degisen  boya
# 0             1 değişen   Galeriden  71300.0        1     0
# 1              1 boyalı   Galeriden  56060.0        0     1
# 2   0 değişen, 0 boyalı  Sahibinden      0.0        0     0
# 3   1 değişen, 4 boyalı   Galeriden      0.0        1     4
# 4   0 değişen, 0 boyalı   Galeriden      0.0        0     0
# 5   0 değişen, 0 boyalı   Galeriden      0.0        0     0
# 6              1 boyalı   Galeriden      0.0        0     1
# 7   0 değişen, 0 boyalı   Galeriden      0.0        0     0
# 8   1 değişen, 1 boyalı   Galeriden   4000.0        1     1
# 9   0 değişen, 0 boyalı   Galeriden      0.0        0     0
# 10            1 değişen   Galeriden      0.0        1     0
# 11            1 değişen   Galeriden      0.0        1     0
# 12        Belirtilmemiş   Galeriden      0.0        0     0
# 13  0 değişen, 0 boyalı   Galeriden      0.0        0     0
# 14        Belirtilmemiş   Galeriden      0.0        0     0
#
# [15 rows x 25 columns]

# %%
cd['fiyat'] = cd['fiyat'].str.replace(' TL', '', regex=False).str.replace('.', '', regex=False).astype(float)

cd['kilometre'] = cd['kilometre'].str.replace(' km', '', regex=False).str.replace('.', '', regex=False).astype(float)

cd['ortalama_yakit_tuketimi'] = cd['ortalama_yakit_tuketimi'].str.replace(' lt', '', regex=False).str.replace(',', '.', regex=False).astype(float)

cd['yakit_deposu'] = cd['yakit_deposu'].str.replace(' lt', '', regex=False).astype(float)

# %%
cd['motor_gucu'] = cd['motor_gucu'].str.replace(' HP', '', regex=False)
cd['motor_gucu'] = cd['motor_gucu'].str.replace(' hp', '', regex=False)

# %%
cd['motor_hacmi'] = cd['motor_hacmi'].str.replace(' cm3', '', regex=False)
cd['motor_hacmi'] = cd['motor_hacmi'].str.replace(' cc', '', regex=False)

# %%
bagimsiz_degisken=cd[["konum","marka","seri","model","yil","kilometre","vites_tipi","yakit_tipi","kasa_tipi","renk","motor_hacmi","motor_gucu","cekis","ortalama_yakit_tuketimi","yakit_deposu","tramer","degisen","boya"]]
bagimli_degisken=cd["fiyat"]

kategori=["konum","marka","seri","model","vites_tipi","yakit_tipi","kasa_tipi","renk","cekis"]

model = CatBoostRegressor(cat_features=kategori, verbose=0)
model.fit(bagimsiz_degisken, bagimli_degisken)

model.save_model("araba_fiyat_model.cbm")
